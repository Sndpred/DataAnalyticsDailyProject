# %%
#install kagglehub library
# !pip install kagglehub

#import necessary library
import pandas as pd
import numpy as np

import kagglehub

# Download the latest version
path = kagglehub.dataset_download("saurabh00007/iriscsv")

print("Path to dataset files:", path)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 2.9 MB/s eta 0:00:00
# ...
# 100%|█████████████████████████████████████| 1.28k/1.28k [00:00<00:00, 892kB/s]
# Extracting files...
# Path to dataset files: /Users/sndpred/.cache/kagglehub/datasets/saurabh00007/iriscsv/versions/1

# %%
#load data from a CSV file
df = pd.read_csv('/Users/sndpred/.cache/kagglehub/datasets/saurabh00007/iriscsv/versions/1/iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Data Inspection
#display first five rows of dataset.
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#display last five rows of dataset.
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#display information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Selecting Values
#printing values for species
df["Species"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df.iloc[0]
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
#Filter Data
df[df['PetalLengthCm'] > 1.5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 11    12            4.8           3.4            1.6           0.2
# 18    19            5.7           3.8            1.7           0.3
# 20    21            5.4           3.4            1.7           0.2
# 23    24            5.1           3.3            1.7           0.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 5       Iris-setosa
# 11      Iris-setosa
# 18      Iris-setosa
# 20      Iris-setosa
# 23      Iris-setosa
# ..              ...
# ...

# %%
#add and remove columns
df['Sepal'] = df['SepalLengthCm'] + df['SepalWidthCm']
df['Sepal']
# Out:
# 0      8.6
# 1      7.9
# 2      7.9
# 3      7.7
# 4      8.6
#       ...
# 145    9.7
# 146    8.8
# 147    9.5
# 148    9.6
# 149    8.9
# Name: Sepal, Length: 150, dtype: float64

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Sepal
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
#Remove a column
df.drop('Sepal', axis=1, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.drop(3, axis=0, inplace=True)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# ...

# %%
#Rename column
df.columns = ["ID", "SepalWidthCm", "SepalWidth", "PetalLength", "PetalWidth", "Species"]
df
# Out:
#       ID  SepalWidthCm  SepalWidth  PetalLength  PetalWidth         Species
# 0      1           5.1         3.5          1.4         0.2     Iris-setosa
# 1      2           4.9         3.0          1.4         0.2     Iris-setosa
# 2      3           4.7         3.2          1.3         0.2     Iris-setosa
# 4      5           5.0         3.6          1.4         0.2     Iris-setosa
# 5      6           5.4         3.9          1.7         0.4     Iris-setosa
# ..   ...           ...         ...          ...         ...             ...
# 145  146           6.7         3.0          5.2         2.3  Iris-virginica
# 146  147           6.3         2.5          5.0         1.9  Iris-virginica
# 147  148           6.5         3.0          5.2         2.0  Iris-virginica
# 148  149           6.2         3.4          5.4         2.3  Iris-virginica
# 149  150           5.9         3.0          5.1         1.8  Iris-virginica
#
# [149 rows x 6 columns]

# %%
#df.rename(columns={'Oldname':'Newname'},inplace=True)

# %%
#grouping data
grouped_data = df.groupby('Species').mean()
grouped_data
# Out:
#                          ID  SepalWidthCm  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-setosa       25.938776      5.014286     3.42449     1.463265    0.244898
# Iris-versicolor   75.500000      5.936000     2.77000     4.260000    1.326000
# Iris-virginica   125.500000      6.588000     2.97400     5.552000    2.026000

# %%
#mean of single column
df["PetalLength"].mean()
# Out:
# 3.773825503355704

# %%
#sorting data

df.sort_values(by='PetalWidth', ascending=False)
# Out:
#       ID  SepalWidthCm  SepalWidth  PetalLength  PetalWidth         Species
# 144  145           6.7         3.3          5.7         2.5  Iris-virginica
# 109  110           7.2         3.6          6.1         2.5  Iris-virginica
# 100  101           6.3         3.3          6.0         2.5  Iris-virginica
# 114  115           5.8         2.8          5.1         2.4  Iris-virginica
# 140  141           6.7         3.1          5.6         2.4  Iris-virginica
# ..   ...           ...         ...          ...         ...             ...
# 37    38           4.9         3.1          1.5         0.1     Iris-setosa
# 9     10           4.9         3.1          1.5         0.1     Iris-setosa
# 34    35           4.9         3.1          1.5         0.1     Iris-setosa
# 32    33           5.2         4.1          1.5         0.1     Iris-setosa
# 12    13           4.8         3.0          1.4         0.1     Iris-setosa
#
# [149 rows x 6 columns]

# %%
#Data Cleaning with Pandas
df.describe()
# Out:
#                ID  SepalWidthCm  SepalWidth  PetalLength  PetalWidth
# count  149.000000    149.000000  149.000000   149.000000  149.000000
# mean    75.979866      5.851678    3.053691     3.773826    1.205369
# std     43.191195      0.824507    0.435040     1.760543    0.761292
# min      1.000000      4.300000    2.000000     1.000000    0.100000
# 25%     39.000000      5.100000    2.800000     1.600000    0.300000
# 50%     76.000000      5.800000    3.000000     4.400000    1.300000
# 75%    113.000000      6.400000    3.300000     5.100000    1.800000
# max    150.000000      7.900000    4.400000     6.900000    2.500000

# %%
#display 12 random data from the dataset
df.sample(12)
# Out:
#       ID  SepalWidthCm  SepalWidth  PetalLength  PetalWidth          Species
# 25    26           5.0         3.0          1.6         0.2      Iris-setosa
# 116  117           6.5         3.0          5.5         1.8   Iris-virginica
# 37    38           4.9         3.1          1.5         0.1      Iris-setosa
# 95    96           5.7         3.0          4.2         1.2  Iris-versicolor
# 122  123           7.7         2.8          6.7         2.0   Iris-virginica
# 40    41           5.0         3.5          1.3         0.3      Iris-setosa
# 127  128           6.1         3.0          4.9         1.8   Iris-virginica
# 106  107           4.9         2.5          4.5         1.7   Iris-virginica
# 10    11           5.4         3.7          1.5         0.2      Iris-setosa
# 129  130           7.2         3.0          5.8         1.6   Iris-virginica
# 9     10           4.9         3.1          1.5         0.1      Iris-setosa
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# ID              0
# SepalWidthCm    0
# SepalWidth      0
# PetalLength     0
# PetalWidth      0
# Species         0
# dtype: int64

# %%
#Handling missing values
#remove rows with missing values

df.dropna(inplace=True)

# %%
#replace with 0
df.fillna(value=0, inplace=True)

# %%
#remove duplicate rows
df.drop_duplicates(inplace=True)
