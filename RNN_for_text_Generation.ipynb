# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.optimizers import Adam

text = ["This is a sample text for a simple recurrent neural network model."]

# Tokenize text
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(text)
sequences = tokenizer.texts_to_sequences(text)[0]

# Prepare sequences
X, y = [], []
seq_length = 3
for i in range(len(sequences) - seq_length):
    X.append(sequences[i:i+seq_length])
    y.append(sequences[i+seq_length])
X, y = np.array(X), np.array(y)

# Build model
model = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=10),  # output_dim is embedding size
    SimpleRNN(50),
    Dense(len(tokenizer.word_index) + 1, activation='softmax')
])

# Compile and train
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
model.fit(X, y, epochs=200, verbose=1)


# Make prediction
input_seq = X[-2]  # for example
prediction = model.predict(np.array([input_seq]), verbose=0)
predicted_word = tokenizer.index_word[np.argmax(prediction)]
print(f"Predicted next word: {predicted_word}")
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.1111 - loss: 2.4734
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3333 - loss: 2.4633
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3333 - loss: 2.4531
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4444 - loss: 2.4430
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4444 - loss: 2.4327
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5556 - loss: 2.4222
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6667 - loss: 2.4116
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6667 - loss: 2.4007
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7778 - loss: 2.3894
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7778 - loss: 2.3778
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7778 - loss: 2.3658
# Epoch 12/200
# ...
